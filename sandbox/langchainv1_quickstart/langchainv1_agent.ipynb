# %%
# !pip install -qU langchain
# !pip install -qU python-dotenv
# !pip install -qU langchain-openai
# Out:
# [notice] A new release of pip is available: 25.1.1 -> 25.3
# [notice] To update, run: pip install --upgrade pip
#
# [notice] A new release of pip is available: 25.1.1 -> 25.3
# [notice] To update, run: pip install --upgrade pip

# %%
from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %%
from langchain.agents import create_agent

def get_weather(city: str) -> str:
    """Get weather for a given city."""
    return f"It's always sunny in {city}!"

agent = create_agent(
    model="openai:gpt-4o",
    #tools=[get_weather],
    #system_prompt="You are a helpful assistant",
)

# Run the agent
result = agent.invoke(
    {"messages": [{"role": "user", "content": "what is the weather in sf"}]}
)

# %%
print(type(result))
# Out:
# <class 'dict'>

# %%
print(result['messages'][0].content)
# Out:
# what is the weather in sf

# %%
print(result['messages'][1])
# Out:
# content="I'm unable to provide real-time weather updates. To get the current weather in San Francisco, you can check a reliable weather website or use a weather app on your smartphone." additional_kwargs={'refusal': None} response_metadata={'token_usage': {'completion_tokens': 34, 'prompt_tokens': 13, 'total_tokens': 47, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-4o-2024-08-06', 'system_fingerprint': 'fp_65564d8ba5', 'id': 'chatcmpl-CZW6pcAyLVy1OVErpp7uYNlbmqAyq', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None} id='lc_run--590f08b1-48d4-44c8-8c3d-a3588c0cf00a-0' usage_metadata={'input_tokens': 13, 'output_tokens': 34, 'total_tokens': 47, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}

# %%
print(result['messages'][2].content)
# Out:
# It's always sunny in San Francisco!
